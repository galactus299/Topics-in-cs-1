# %%
import wikipedia
import pandas as pd

df=pd.DataFrame(columns=['content','url','Title',"category",'summary',"link","reference"])

# %%
searchlist=wikipedia.search('halo',results=3)

for items in searchlist:
    page=wikipedia.page(items)
    df['url']=["".join(page.url)]
    df['content']=["".join(page.content)]
    df['Title']=["".join(page.title)]
    df['summary']=["".join(page.summary)]
    df['link']=["".join(page.links)]
    df['reference']=["".join(page.references)]
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\OneDrive\Desktop\sem7\Topics in cs 1\venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
df

# %%
searchlist=wikipedia.search('halo')

for items in searchlist:
    page=wikipedia.page(items)
    print(page)
